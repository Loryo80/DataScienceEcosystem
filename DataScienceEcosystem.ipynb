# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives**:
#
#  - Creating a Jupyter Notebook using Skills Network LTI item or Watson Studio environment
#  - Create Markdown cells
#  - download the notebook
#  - upload the notebook to IBM watson studio
#  - manipulation of cells (code and markdown)
#  - share the final result on github

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#  1. Python
#  2. R
#  3. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include :
#  1. Pandas
#  2. NumPy
#  3. SciPy
#  4. Matplotlib
#  5. TensorFlow
#  6. SciKit-Learn
#  7. Keras
#  8. PyTorch

# %% [markdown]
# Some popular datas science tools:
#
#
# | Data Science Tool  |
# |------|
# | JupyterLab and Jupyter Notebooks|
# | RStudio|
# | Github|

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python :
#
# Addition = x + y
#
# Subtraction = x - y
#
# Multiplication = x * y
#
# Division = x / y

# %%
#  This a simple arithmetic expression to mutiply then add integers

(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60

def min_to_hour(m):
    h = (m // 60)
    return h
    
m = 200     # minutes 
h = min_to_hour(m)
print(h, "hour(s)")
# Out:
# 3 hour(s)

# %% [markdown]
# ## Author
#
# Yassine SENHAJI
